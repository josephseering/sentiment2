# %%
#test
import csv

with open('intervention.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    
    conditions = []
    comments = []
    
    for row in readCSV:
        condition = row [1]
        comment = row [2]

        print(row[1])
        print(row[2])
# Out:
# control
# Coming from Germany, you should have first hand knowledge of the path Trump is leading us down. When you're ready to have an adult conversation without name calling, perhaps we can move this country forward.
# control
# Congrats on becoming an American citizen. You are a great example of working towards the American dream.
# control
# deplorable might be too nice of a term for you. You seem so entitled because of your hard work, but that doesn't mean that because you work hard you get to be better than anyone else. Check yourself mate
# control
# Everyone has the right to their own opinion and I am glad that you were able to express it in a way that was satisfactory.
# control
# ...

# %%
f = open('intervention.csv', 'r')

import csv
reader = csv.reader(f)


line_number = 0  
comment = []  
intervention = []  
for line in reader:  
    if line_number >= 0:  
        intervention1 = line[1]
        comment1 = line[2]
        if intervention1 == 'control':
            intervention.append(intervention1)
            comment.append(comment1)
    line_number = line_number + 1
    
#print(comment)
#print(intervention)


from afinn import Afinn
afinn = Afinn()

list1 = []
for i in comment:
    list1.append(afinn.score(i))

print(list1)

print(sum(list1)/len(list1))
# Out:
# [2.0, 6.0, 4.0, 3.0, 8.0, 5.0, 3.0, 2.0, 3.0, 0.0, 4.0, 8.0, -2.0, -5.0, 6.0, 6.0, -3.0, 2.0, -9.0, -2.0, -3.0, 5.0, 2.0, 3.0, 8.0, 9.0, -9.0, -3.0, 5.0, 5.0, -3.0, 5.0, -2.0, 7.0, -20.0, 7.0, -1.0, 19.0, 2.0, 2.0, 4.0, -1.0, -2.0, 5.0, -6.0]
# 1.7555555555555555

# %%
from afinn import Afinn

afinn = Afinn()
afinn.score(comment[0])
# Out:
# 2.0

# %%
f = open('intervention.csv', 'r')

import csv
reader = csv.reader(f)


line_number = 0  
comment = []  
intervention = []  
for line in reader:  
    if line_number >= 0:  
        intervention1 = line[1]
        comment1 = line[2]
        if intervention1 == 'scramble-neutral':
            intervention.append(intervention1)
            comment.append(comment1)
    line_number = line_number + 1
    
#print(comment)
#print(intervention)


from afinn import Afinn
afinn = Afinn()

list1 = []
for i in comment:
    list1.append(afinn.score(i))

print(list1)

print(sum(list1)/len(list1))
# Out:
# [-4.0, 2.0, -9.0, 4.0, 5.0, -2.0, 2.0, 0.0, -3.0, -6.0, -4.0, 3.0, 1.0, 4.0, 2.0, 1.0, 2.0, -4.0, -8.0, 1.0, 2.0, -2.0, 1.0, -8.0, 6.0, 0.0, -2.0, 11.0, 0.0, 2.0, 1.0, 3.0, -2.0, 13.0, 0.0, 0.0, 3.0, -11.0, 4.0, 3.0, 6.0, 0.0, -2.0, 1.0, -8.0]
# 0.17777777777777778
